# %% [markdown]
# ## Displaying FSL-corrected images

# %%
push!(LOAD_PATH,"library");
using PyPlot
using NK_tools
using Read_NIfTI1_real

# %% [markdown]
# * __Comparing 2 SENSE produced magnitude images__

# %%
filename = "data/images_to_be_aligned_mcf.nii.gz";
headerinfo = load_niigz_header(filename);
newData = load_niigz_data(filename, headerinfo);
print(size(newData))
figure(1,figsize=(6,3)); imal(newData[:,:,1,:],2,1)
figure(2,figsize=(3,3)); imshow(newData[:,:,1,1]-newData[:,:,1,2],cmap="gray")
# figure(1,figsize=(3,3));imshow(abs.(evensense_reconstructed_image)-abs.(oddsense_reconstructed_image),cmap="gray")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x2aab3ea36c88>)
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x2aab3ea8ce80>)
# (128, 128, 1, 2)262144
# PyObject <matplotlib.image.AxesImage object at 0x2aab3eadfcf8>
